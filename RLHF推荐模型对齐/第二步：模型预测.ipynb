# %%
import json
from openai import OpenAI
from tqdm import tqdm

# 加载模型
client = OpenAI(
    api_key="EMPTY",
    # 需要修改为大模型地址
    base_url="http://10.114.16.65:8000/v1/"
)

# %%
# 加载测试数据
test_file_path = "./data/processed/rlhf_test.json"
with open(test_file_path, "r", encoding='utf-8') as test_file:
    test_data = json.load(test_file)
print(len(test_data))
# Out:
# 1286

# %%
# 开始预测
labels = []
predictions = []
cc = 0
for each_test in tqdm(test_data):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": each_test["instruction"]
            },
            {
                "role": "user",
                "content": each_test["input"],
            }
        ],
        model="glm4",
    )

    predictions.append(chat_completion.choices[0].message.content)
    labels.append(each_test["chosen"])

    if len(labels) % 100 == 0:
        correct = 0
        wrong = 0

        for l, p in zip(labels, predictions):
            l = l.strip()
            p = p.strip()
            # print(f'l: {l}, p: {p}')
            
            if l == p:
                correct += 1
            else:
                wrong += 1
                # print(f'\nl: {l}, \np: {p}')
        print(f'总样本数：{len(labels)}，准确数：{correct}, 错误数：{wrong}, 准确率：{correct / len(labels)}')
    cc += 1
    
    # if cc > 100:
    #     break

assert len(predictions) == len(labels)

correct = 0
wrong = 0

for l, p in zip(labels, predictions):
    l = l.strip()
    p = p.strip()
    if l == p:
        correct += 1
    else:
        wrong += 1
print(f'总样本数：{len(labels)}，准确数：{correct}, 错误数：{wrong}, 准确率：{correct/len(labels)}')
# Out:
#   8%|███████▏                                                                                    | 100/1286 [01:56<20:28,  1.04s/it]
# 总样本数：100，准确数：55, 错误数：45, 准确率：0.55
#  16%|██████████████▎                                                                             | 200/1286 [04:02<19:25,  1.07s/it]
# 总样本数：200，准确数：105, 错误数：95, 准确率：0.525
#  23%|█████████████████████▍                                                                      | 300/1286 [06:06<18:16,  1.11s/it]
# 总样本数：300，准确数：165, 错误数：135, 准确率：0.55
#  31%|████████████████████████████▌                                                               | 400/1286 [07:57<14:32,  1.02it/s]
# 总样本数：400，准确数：221, 错误数：179, 准确率：0.5525
#  39%|███████████████████████████████████▊                                                        | 500/1286 [09:50<13:55,  1.06s/it]
# 总样本数：500，准确数：271, 错误数：229, 准确率：0.542
#  47%|██████████████████████████████████████████▉                                                 | 600/1286 [11:41<11:51,  1.04s/it]
# 总样本数：600，准确数：327, 错误数：273, 准确率：0.545
#  54%|██████████████████████████████████████████████████                                          | 700/1286 [13:37<08:26,  1.16it/s]
# 总样本数：700，准确数：386, 错误数：314, 准确率：0.5514285714285714
#  62%|█████████████████████████████████████████████████████████▏                                  | 800/1286 [15:47<07:09,  1.13it/s]
# 总样本数：800，准确数：441, 错误数：359, 准确率：0.55125
#  70%|████████████████████████████████████████████████████████████████▍                           | 900/1286 [17:44<05:56,  1.08it/s]
# 总样本数：900，准确数：495, 错误数：405, 准确率：0.55
#  78%|██████████████████████████████████████████████████████████████████████▊                    | 1000/1286 [19:40<05:07,  1.08s/it]
# 总样本数：1000，准确数：552, 错误数：448, 准确率：0.552
#  86%|█████████████████████████████████████████████████████████████████████████████▊             | 1100/1286 [21:42<03:52,  1.25s/it]
# 总样本数：1100，准确数：610, 错误数：490, 准确率：0.5545454545454546
#  93%|████████████████████████████████████████████████████████████████████████████████████▉      | 1200/1286 [23:35<01:30,  1.05s/it]
# 总样本数：1200，准确数：671, 错误数：529, 准确率：0.5591666666666667
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1286/1286 [25:14<00:00,  1.18s/it]
# 总样本数：1286，准确数：719, 错误数：567, 准确率：0.5590979782270606
